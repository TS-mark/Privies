# %%
from torchvision.transforms import v2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from torchvision.transforms import v2
#
# ImportError: cannot import name 'v2' from 'torchvision.transforms' (c:\Users\mark\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\transforms\__init__.py)

# %%
# !pip install torch==2.1
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/192.3 MB 217.9 kB/s eta 0:14:43
#    ---------------------------------------- 0.0/192.3 MB 245.8 kB/s eta 0:13:03
#    ---------------------------------------- 0.1/192.3 MB 297.7 kB/s eta 0:10:46
#    ---------------------------------------- 0.1/192.3 MB 280.5 kB/s eta 0:11:26
#    ---------------------------------------- 0.1/192.3 MB 308.0 kB/s eta 0:10:25
#    ---------------------------------------- 0.1/192.3 MB 343.4 kB/s eta 0:09:20
#    ---------------------------------------- 0.2/192.3 MB 416.7 kB/s eta 0:07:42
#    ---------------------------------------- 0.2/192.3 MB 509.6 kB/s eta 0:06:17
#    ---------------------------------------- 0.2/192.3 MB 514.3 kB/s eta 0:06:14
# ...
